# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
yy = [-5,8,4,0,-4,6,1,7,-5,-1,4]
y = pd.Series(yy)
print(y)
plt.plot(y)
plt.show()
# Out:
# 0    -5
# 1     8
# 2     4
# 3     0
# 4    -4
# 5     6
# 6     1
# 7     7
# 8    -5
# 9    -1
# 10    4
# dtype: int64

# %%
yr = np.random.random(20)
d1 = pd.date_range('1990',periods = len(yr),freq)
y = pd.Series(yr,index=d1)
print(y)
plt.plot(y)
plt.show()
# Out:
# 1990-10-27    0.844779
# 1990-10-28    0.772587
# 1990-10-29    0.973292
# 1990-10-30    0.295826
# 1990-10-31    0.006876
# 1990-11-01    0.091966
# 1990-11-02    0.501025
# 1990-11-03    0.215380
# 1990-11-04    0.399275
# 1990-11-05    0.671598
# 1990-11-06    0.497390
# 1990-11-07    0.119742
# 1990-11-08    0.460027
# 1990-11-09    0.119170
# 1990-11-10    0.914924
# 1990-11-11    0.583567
# 1990-11-12    0.481192
# 1990-11-13    0.045774
# 1990-11-14    0.262711
# 1990-11-15    0.973995
# Freq: D, dtype: float64

# %%
dates = pd.date_range('1950', '2012', freq='M')
print dates.shape
dat = np.random.random(size(dates))
AO = pd.Series(dat, index=dates)
AO.plot()
plt.show()
# Out:
# (744,)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Time Series
yr = np.random.random(21)
#d1 = pd.date_range('1990',periods = len(yr),freq='M')
d2 = pd.date_range('1990','2011',freq='A')
y = pd.Series(yr,index=d2)
y.plot(style='b-*', label='Series')
plt.legend(frameon=False)
plt.grid(True)
plt.show()
